# %%
import requests
from bs4 import BeautifulSoup
import textwrap

# %%
# Set up headers to mimic a browser visit
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Referer": "https://google.com"
}


# Fetch and parse the webpage
url = 'https://understandingwar.org/research/russia-ukraine/russian-offensive-campaign-assessment-november-4-2025/'
response = requests.get(url, headers=headers)
html = response.text

# Parse with BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')


# # Extract all visible text
# text = soup.get_text(separator="\n", strip=True)

# # Print or save the result
# print(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       1 # Set up headers to mimic a browser visit
#       2 headers = {
#       3     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
#       4     "Accept-Language": "en-US,en;q=0.9",
#       5     "Referer": "https://google.com"
#       6 }
# ----> 9 a# Fetch and parse the webpage
#      10 url = 'https://understandingwar.org/research/russia-ukraine/russian-offensive-campaign-assessment-november-4-2025/'
#      11 response = requests.get(url, headers=headers)
#
# NameError: name 'a' is not defined
